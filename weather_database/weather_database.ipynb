# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 776

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

time.sleep(60)
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cherskiy
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | pisco
# Processing Record 4 of Set 1 | mahebourg
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | daxian
# City not found. Skipping...
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | khash
# Processing Record 10 of Set 1 | yanam
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | codrington
# Processing Record 13 of Set 1 | katsuura
# Processing Record 14 of Set 1 | gazli
# Processing Record 15 of Set 1 | bossangoa
# Processing Record 16 of Set 1 | taltal
# Processing Record 17 of Set 1 | kodiak
# Processing Record 18 of Set 1 | lazaro cardenas
# Processing Record 19 of Set 1 | la ronge
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | fairbanks
# Processing Record 22 of Set 1 | itoman
# Processing Record 23 of Set 1 | nelson bay
# Processing Record 24 of Set 1 | punta arenas
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | kuching
# Processing Record 27 of Set 1 | sept-iles
# Processing Record 28 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 1 | sur
# Processing Record 30 of Set 1 | tuatapere
# Processing Record 31 of Set 1 | nikolskoye
# Processing Record 32 of Set 1 | castro
# Processing Record 33 of Set 1 | bengkulu
# Processing Record 34 of Set 1 | harper
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | yerbogachen
# Processing Record 37 of Set 1 | irbeyskoye
# Processing Record 38 of Set 1 | boulder city
# Processing Record 39 of Set 1 | veraval
# Processing Record 40 of Set 1 | zaria
# Processing Record 41 of Set 1 | ati
# Processing Record 42 of Set 1 | dongsheng
# Processing Record 43 of Set 1 | nantucket
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | adrar
# Processing Record 46 of Set 1 | jamestown
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | ostrovnoy
# Processing Record 49 of Set 1 | poum
# Processing Record 50 of Set 1 | beira
# Processing Record 1 of Set 2 | bathsheba
# Processing Record 2 of Set 2 | sao filipe
# Processing Record 3 of Set 2 | chateauroux
# Processing Record 4 of Set 2 | yeniseysk
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | kavaratti
# Processing Record 7 of Set 2 | rovaniemi
# Processing Record 8 of Set 2 | vila velha
# Processing Record 9 of Set 2 | cabo san lucas
# Processing Record 10 of Set 2 | dogbo
# Processing Record 11 of Set 2 | tuktoyaktuk
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | nago
# Processing Record 15 of Set 2 | entebbe
# Processing Record 16 of Set 2 | grand gaube
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | puerto quijarro
# Processing Record 19 of Set 2 | nouadhibou
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | tilichiki
# Processing Record 22 of Set 2 | hofn
# Processing Record 23 of Set 2 | saint george
# Processing Record 24 of Set 2 | fortuna
# Processing Record 25 of Set 2 | finschhafen
# Processing Record 26 of Set 2 | nanortalik
# Processing Record 27 of Set 2 | hermanus
# Processing Record 28 of Set 2 | prince rupert
# Processing Record 29 of Set 2 | hambantota
# Processing Record 30 of Set 2 | barrow
# Processing Record 31 of Set 2 | tarakan
# Processing Record 32 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 2 | dumas
# Processing Record 34 of Set 2 | fatikchhari
# City not found. Skipping...
# Processing Record 35 of Set 2 | ferme-neuve
# Processing Record 36 of Set 2 | hervey bay
# Processing Record 37 of Set 2 | itapirapua
# Processing Record 38 of Set 2 | qaanaaq
# Processing Record 39 of Set 2 | taksimo
# Processing Record 40 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 2 | sungaipenuh
# Processing Record 42 of Set 2 | lebu
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | preston
# Processing Record 45 of Set 2 | letpadan
# Processing Record 46 of Set 2 | kunya
# Processing Record 47 of Set 2 | koungou
# Processing Record 48 of Set 2 | anloga
# Processing Record 49 of Set 2 | atuona
# Processing Record 50 of Set 2 | port lincoln
# Processing Record 1 of Set 3 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 3 | souillac
# Processing Record 3 of Set 3 | tasiilaq
# Processing Record 4 of Set 3 | kavieng
# Processing Record 5 of Set 3 | santa fe
# Processing Record 6 of Set 3 | provideniya
# Processing Record 7 of Set 3 | mar del plata
# Processing Record 8 of Set 3 | miranda
# Processing Record 9 of Set 3 | remanso
# Processing Record 10 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 3 | ningan
# City not found. Skipping...
# Processing Record 12 of Set 3 | ahipara
# Processing Record 13 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 14 of Set 3 | saint-ambroise
# Processing Record 15 of Set 3 | stiubieni
# Processing Record 16 of Set 3 | cidreira
# Processing Record 17 of Set 3 | fernley
# Processing Record 18 of Set 3 | orai
# Processing Record 19 of Set 3 | el reno
# Processing Record 20 of Set 3 | khatanga
# Processing Record 21 of Set 3 | yellowknife
# Processing Record 22 of Set 3 | klaksvik
# Processing Record 23 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 3 | zaraza
# Processing Record 25 of Set 3 | stromness
# Processing Record 26 of Set 3 | deputatskiy
# Processing Record 27 of Set 3 | mata
# Processing Record 28 of Set 3 | upernavik
# Processing Record 29 of Set 3 | sumbuya
# Processing Record 30 of Set 3 | ukiah
# Processing Record 31 of Set 3 | shima
# Processing Record 32 of Set 3 | kaitangata
# Processing Record 33 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 3 | new norfolk
# Processing Record 35 of Set 3 | barranca
# Processing Record 36 of Set 3 | south venice
# Processing Record 37 of Set 3 | lithakia
# Processing Record 38 of Set 3 | bredasdorp
# Processing Record 39 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 3 | tezu
# Processing Record 41 of Set 3 | bulgan
# Processing Record 42 of Set 3 | thompson
# Processing Record 43 of Set 3 | sao joao da barra
# Processing Record 44 of Set 3 | aklavik
# Processing Record 45 of Set 3 | kapaa
# Processing Record 46 of Set 3 | tondano
# Processing Record 47 of Set 3 | les cayes
# Processing Record 48 of Set 3 | kochi
# Processing Record 49 of Set 3 | malegaon
# Processing Record 50 of Set 3 | pakenham
# Processing Record 1 of Set 4 | clyde river
# Processing Record 2 of Set 4 | trairi
# Processing Record 3 of Set 4 | shakhovskaya
# Processing Record 4 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 4 | kirakira
# Processing Record 6 of Set 4 | kankon
# Processing Record 7 of Set 4 | bambous virieux
# Processing Record 8 of Set 4 | talnakh
# Processing Record 9 of Set 4 | ust-tsilma
# Processing Record 10 of Set 4 | constantine
# Processing Record 11 of Set 4 | dikson
# Processing Record 12 of Set 4 | pangnirtung
# Processing Record 13 of Set 4 | mountain home
# Processing Record 14 of Set 4 | oranjestad
# Processing Record 15 of Set 4 | antsohihy
# Processing Record 16 of Set 4 | flinders
# Processing Record 17 of Set 4 | chuy
# Processing Record 18 of Set 4 | bijie
# Processing Record 19 of Set 4 | corrientes
# Processing Record 20 of Set 4 | afrikanda
# Processing Record 21 of Set 4 | mabaruma
# Processing Record 22 of Set 4 | ponta do sol
# Processing Record 23 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 4 | palmer
# Processing Record 25 of Set 4 | tahta
# Processing Record 26 of Set 4 | ancud
# Processing Record 27 of Set 4 | inhambane
# Processing Record 28 of Set 4 | butaritari
# Processing Record 29 of Set 4 | machado
# Processing Record 30 of Set 4 | tukrah
# Processing Record 31 of Set 4 | east london
# Processing Record 32 of Set 4 | arraial do cabo
# Processing Record 33 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 4 | khani
# Processing Record 35 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 4 | takoradi
# Processing Record 37 of Set 4 | falmouth
# Processing Record 38 of Set 4 | mbuji-mayi
# Processing Record 39 of Set 4 | cabra
# Processing Record 40 of Set 4 | bandarbeyla
# Processing Record 41 of Set 4 | pokhara
# Processing Record 42 of Set 4 | maloy
# Processing Record 43 of Set 4 | thilogne
# City not found. Skipping...
# Processing Record 44 of Set 4 | westport
# Processing Record 45 of Set 4 | chokurdakh
# Processing Record 46 of Set 4 | seddon
# Processing Record 47 of Set 4 | kargasok
# Processing Record 48 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 4 | naze
# Processing Record 50 of Set 4 | marawi
# Processing Record 1 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 5 | hasaki
# Processing Record 3 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 5 | buraydah
# Processing Record 5 of Set 5 | yantzaza
# Processing Record 6 of Set 5 | richards bay
# Processing Record 7 of Set 5 | waingapu
# Processing Record 8 of Set 5 | srednekolymsk
# Processing Record 9 of Set 5 | leningradskiy
# Processing Record 10 of Set 5 | vila
# Processing Record 11 of Set 5 | vardo
# Processing Record 12 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 5 | saint anthony
# Processing Record 14 of Set 5 | dinghai
# Processing Record 15 of Set 5 | belmonte
# Processing Record 16 of Set 5 | lasa
# Processing Record 17 of Set 5 | blind river
# Processing Record 18 of Set 5 | wajima
# Processing Record 19 of Set 5 | san carlos
# Processing Record 20 of Set 5 | fomboni
# Processing Record 21 of Set 5 | pekan
# Processing Record 22 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 23 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 5 | kieta
# Processing Record 25 of Set 5 | floro
# Processing Record 26 of Set 5 | bethel
# Processing Record 27 of Set 5 | zhigansk
# Processing Record 28 of Set 5 | constitucion
# Processing Record 29 of Set 5 | show low
# Processing Record 30 of Set 5 | balagansk
# Processing Record 31 of Set 5 | inegol
# Processing Record 32 of Set 5 | puerto lleras
# Processing Record 33 of Set 5 | high rock
# Processing Record 34 of Set 5 | marsa matruh
# Processing Record 35 of Set 5 | carnarvon
# Processing Record 36 of Set 5 | padang
# Processing Record 37 of Set 5 | graham
# Processing Record 38 of Set 5 | bozeman
# Processing Record 39 of Set 5 | reidsville
# Processing Record 40 of Set 5 | high level
# Processing Record 41 of Set 5 | scottsboro
# Processing Record 42 of Set 5 | inta
# Processing Record 43 of Set 5 | beidao
# Processing Record 44 of Set 5 | gat
# Processing Record 45 of Set 5 | oktyabrskoye
# Processing Record 46 of Set 5 | iralaya
# Processing Record 47 of Set 5 | lobito
# Processing Record 48 of Set 5 | tessalit
# Processing Record 49 of Set 5 | barbate
# Processing Record 50 of Set 5 | grindavik
# Processing Record 1 of Set 6 | panzhihua
# Processing Record 2 of Set 6 | ribnica
# Processing Record 3 of Set 6 | mayo
# Processing Record 4 of Set 6 | kegayli
# City not found. Skipping...
# Processing Record 5 of Set 6 | marovoay
# Processing Record 6 of Set 6 | tiksi
# Processing Record 7 of Set 6 | ilinskaya
# Processing Record 8 of Set 6 | trinidad
# Processing Record 9 of Set 6 | pacific grove
# Processing Record 10 of Set 6 | port elizabeth
# Processing Record 11 of Set 6 | praia
# Processing Record 12 of Set 6 | broome
# Processing Record 13 of Set 6 | korla
# Processing Record 14 of Set 6 | wattegama
# Processing Record 15 of Set 6 | ambon
# Processing Record 16 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 6 | palu
# Processing Record 18 of Set 6 | boa vista
# Processing Record 19 of Set 6 | san jorge
# Processing Record 20 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 21 of Set 6 | mount gambier
# Processing Record 22 of Set 6 | dali
# Processing Record 23 of Set 6 | opuwo
# Processing Record 24 of Set 6 | uvat
# Processing Record 25 of Set 6 | roma
# Processing Record 26 of Set 6 | victoria
# Processing Record 27 of Set 6 | yulara
# Processing Record 28 of Set 6 | alofi
# Processing Record 29 of Set 6 | jardim
# Processing Record 30 of Set 6 | hokitika
# Processing Record 31 of Set 6 | tchollire
# Processing Record 32 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 33 of Set 6 | cotorra
# Processing Record 34 of Set 6 | ust-nera
# Processing Record 35 of Set 6 | narsaq
# Processing Record 36 of Set 6 | acarau
# Processing Record 37 of Set 6 | port keats
# Processing Record 38 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 6 | lata
# Processing Record 40 of Set 6 | los llanos de aridane
# Processing Record 41 of Set 6 | nemuro
# Processing Record 42 of Set 6 | shimoda
# Processing Record 43 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 6 | borujerd
# Processing Record 45 of Set 6 | durban
# Processing Record 46 of Set 6 | itarema
# Processing Record 47 of Set 6 | cahors
# Processing Record 48 of Set 6 | kruisfontein
# Processing Record 49 of Set 6 | faanui
# Processing Record 50 of Set 6 | ghanzi
# Processing Record 1 of Set 7 | robore
# Processing Record 2 of Set 7 | labuhan
# Processing Record 3 of Set 7 | sorel
# Processing Record 4 of Set 7 | sitka
# Processing Record 5 of Set 7 | howard springs
# Processing Record 6 of Set 7 | shiloh
# Processing Record 7 of Set 7 | sao goncalo
# Processing Record 8 of Set 7 | san andres
# Processing Record 9 of Set 7 | redcar
# Processing Record 10 of Set 7 | maneadero
# Processing Record 11 of Set 7 | egvekinot
# Processing Record 12 of Set 7 | luderitz
# Processing Record 13 of Set 7 | hamilton
# Processing Record 14 of Set 7 | ballina
# Processing Record 15 of Set 7 | anchorage
# Processing Record 16 of Set 7 | araouane
# Processing Record 17 of Set 7 | tabuk
# Processing Record 18 of Set 7 | bayburt
# Processing Record 19 of Set 7 | margate
# Processing Record 20 of Set 7 | esperance
# Processing Record 21 of Set 7 | marrakesh
# Processing Record 22 of Set 7 | palamos
# Processing Record 23 of Set 7 | matamoros
# Processing Record 24 of Set 7 | florianopolis
# Processing Record 25 of Set 7 | ipameri
# Processing Record 26 of Set 7 | salalah
# Processing Record 27 of Set 7 | acapulco
# Processing Record 28 of Set 7 | mahenge
# Processing Record 29 of Set 7 | caiaponia
# Processing Record 30 of Set 7 | cayenne
# Processing Record 31 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 7 | riviere-au-renard
# Processing Record 33 of Set 7 | paso de los toros
# Processing Record 34 of Set 7 | bismarck
# Processing Record 35 of Set 7 | yichang
# Processing Record 36 of Set 7 | valjala
# City not found. Skipping...
# Processing Record 37 of Set 7 | bayir
# Processing Record 38 of Set 7 | ayr
# Processing Record 39 of Set 7 | melenki
# Processing Record 40 of Set 7 | byron bay
# Processing Record 41 of Set 7 | grand forks
# Processing Record 42 of Set 7 | san carlos de bariloche
# Processing Record 43 of Set 7 | laguna
# Processing Record 44 of Set 7 | gumushane
# City not found. Skipping...
# Processing Record 45 of Set 7 | fanai
# Processing Record 46 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 7 | windhoek
# Processing Record 48 of Set 7 | mansa
# Processing Record 49 of Set 7 | ilulissat
# Processing Record 50 of Set 7 | ust-kuyga
# Processing Record 1 of Set 8 | longyearbyen
# Processing Record 2 of Set 8 | severo-kurilsk
# Processing Record 3 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 4 of Set 8 | zyryanka
# Processing Record 5 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 8 | avera
# Processing Record 7 of Set 8 | port blair
# Processing Record 8 of Set 8 | nome
# Processing Record 9 of Set 8 | kardla
# Processing Record 10 of Set 8 | karpogory
# Processing Record 11 of Set 8 | torbay
# Processing Record 12 of Set 8 | bosobolo
# Processing Record 13 of Set 8 | iquique
# Processing Record 14 of Set 8 | doha
# Processing Record 15 of Set 8 | isangel
# Processing Record 16 of Set 8 | bilma
# Processing Record 17 of Set 8 | monatele
# City not found. Skipping...
# Processing Record 18 of Set 8 | genhe
# Processing Record 19 of Set 8 | cortez
# Processing Record 20 of Set 8 | half moon bay
# Processing Record 21 of Set 8 | nizhniy kuranakh
# Processing Record 22 of Set 8 | guerrero negro
# Processing Record 23 of Set 8 | nargana
# Processing Record 24 of Set 8 | lavrentiya
# Processing Record 25 of Set 8 | aktyubinskiy
# Processing Record 26 of Set 8 | san cristobal
# Processing Record 27 of Set 8 | tabou
# Processing Record 28 of Set 8 | cartersville
# Processing Record 29 of Set 8 | cairns
# Processing Record 30 of Set 8 | sobolevo
# Processing Record 31 of Set 8 | leh
# Processing Record 32 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 8 | bayan
# Processing Record 34 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 8 | wangaratta
# Processing Record 36 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 37 of Set 8 | chicama
# Processing Record 38 of Set 8 | harnosand
# Processing Record 39 of Set 8 | hirara
# Processing Record 40 of Set 8 | lorengau
# Processing Record 41 of Set 8 | aitape
# Processing Record 42 of Set 8 | kilindoni
# Processing Record 43 of Set 8 | tazovskiy
# Processing Record 44 of Set 8 | ko samui
# Processing Record 45 of Set 8 | camana
# Processing Record 46 of Set 8 | roebourne
# Processing Record 47 of Set 8 | mitsamiouli
# Processing Record 48 of Set 8 | kawalu
# Processing Record 49 of Set 8 | darfield
# Processing Record 50 of Set 8 | prince albert
# Processing Record 1 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 9 | saint-joseph
# Processing Record 3 of Set 9 | bangolo
# Processing Record 4 of Set 9 | luba
# Processing Record 5 of Set 9 | viedma
# Processing Record 6 of Set 9 | georgetown
# Processing Record 7 of Set 9 | jieshi
# Processing Record 8 of Set 9 | phan thiet
# Processing Record 9 of Set 9 | yuksekova
# Processing Record 10 of Set 9 | kuusamo
# Processing Record 11 of Set 9 | san bernardo
# Processing Record 12 of Set 9 | rawson
# Processing Record 13 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 9 | maku
# Processing Record 15 of Set 9 | aksay
# Processing Record 16 of Set 9 | chumikan
# Processing Record 17 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 18 of Set 9 | berlevag
# Processing Record 19 of Set 9 | pokrovsk
# Processing Record 20 of Set 9 | kahului
# Processing Record 21 of Set 9 | kamaishi
# Processing Record 22 of Set 9 | sortland
# Processing Record 23 of Set 9 | vestbygda
# City not found. Skipping...
# Processing Record 24 of Set 9 | arman
# Processing Record 25 of Set 9 | pemangkat
# Processing Record 26 of Set 9 | ormara
# Processing Record 27 of Set 9 | synya
# Processing Record 28 of Set 9 | dusti
# Processing Record 29 of Set 9 | olinda
# Processing Record 30 of Set 9 | evensk
# Processing Record 31 of Set 9 | qasigiannguit
# Processing Record 32 of Set 9 | tomatlan
# Processing Record 33 of Set 9 | locri
# Processing Record 34 of Set 9 | warrnambool
# Processing Record 35 of Set 9 | lakatoro
# Processing Record 36 of Set 9 | washington
# Processing Record 37 of Set 9 | pierre
# Processing Record 38 of Set 9 | vredendal
# Processing Record 39 of Set 9 | vuktyl
# Processing Record 40 of Set 9 | te anau
# Processing Record 41 of Set 9 | yanchukan
# City not found. Skipping...
# Processing Record 42 of Set 9 | hakkari
# Processing Record 43 of Set 9 | taga dzong
# City not found. Skipping...
# Processing Record 44 of Set 9 | saint-georges
# Processing Record 45 of Set 9 | pevek
# Processing Record 46 of Set 9 | ambulu
# Processing Record 47 of Set 9 | atar
# Processing Record 48 of Set 9 | muswellbrook
# Processing Record 49 of Set 9 | vila franca do campo
# Processing Record 50 of Set 9 | waipawa
# Processing Record 1 of Set 10 | mount isa
# Processing Record 2 of Set 10 | cherepanovo
# Processing Record 3 of Set 10 | port-gentil
# Processing Record 4 of Set 10 | eydhafushi
# Processing Record 5 of Set 10 | dzhebariki-khaya
# Processing Record 6 of Set 10 | broken hill
# Processing Record 7 of Set 10 | north bend
# Processing Record 8 of Set 10 | touros
# Processing Record 9 of Set 10 | wad madani
# Processing Record 10 of Set 10 | tandil
# Processing Record 11 of Set 10 | khandyga
# Processing Record 12 of Set 10 | svetlyy
# Processing Record 13 of Set 10 | komsomolskiy
# Processing Record 14 of Set 10 | ndiekro
# City not found. Skipping...
# Processing Record 15 of Set 10 | flagstaff
# Processing Record 16 of Set 10 | sungairaya
# Processing Record 17 of Set 10 | juneau
# Processing Record 18 of Set 10 | bobrovka
# Processing Record 19 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 20 of Set 10 | nichlaul
# Processing Record 21 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 10 | bandundu
# Processing Record 23 of Set 10 | namatanai
# Processing Record 24 of Set 10 | natal
# Processing Record 25 of Set 10 | aden
# Processing Record 26 of Set 10 | sao francisco do sul
# Processing Record 27 of Set 10 | ngunguru
# Processing Record 28 of Set 10 | wilmington
# Processing Record 29 of Set 10 | geraldton
# Processing Record 30 of Set 10 | shumskiy
# Processing Record 31 of Set 10 | yarada
# Processing Record 32 of Set 10 | apaxtla
# City not found. Skipping...
# Processing Record 33 of Set 10 | yaan
# Processing Record 34 of Set 10 | pauini
# Processing Record 35 of Set 10 | kenora
# Processing Record 36 of Set 10 | ercis
# Processing Record 37 of Set 10 | fort nelson
# Processing Record 38 of Set 10 | kamenolomni
# Processing Record 39 of Set 10 | rio grande
# Processing Record 40 of Set 10 | faranah
# Processing Record 41 of Set 10 | mingshui
# Processing Record 42 of Set 10 | ucluelet
# Processing Record 43 of Set 10 | jawar
# Processing Record 44 of Set 10 | muzquiz
# City not found. Skipping...
# Processing Record 45 of Set 10 | jerome
# Processing Record 46 of Set 10 | qafsah
# City not found. Skipping...
# Processing Record 47 of Set 10 | zanjan
# Processing Record 48 of Set 10 | weligama
# Processing Record 49 of Set 10 | lagoa
# Processing Record 50 of Set 10 | alyangula
# Processing Record 1 of Set 11 | koygorodok
# Processing Record 2 of Set 11 | chifeng
# Processing Record 3 of Set 11 | santo antonio do ica
# Processing Record 4 of Set 11 | sumbe
# Processing Record 5 of Set 11 | nikko
# Processing Record 6 of Set 11 | skjervoy
# Processing Record 7 of Set 11 | polunochnoye
# Processing Record 8 of Set 11 | vrangel
# Processing Record 9 of Set 11 | tolaga bay
# Processing Record 10 of Set 11 | baghmara
# Processing Record 11 of Set 11 | lima
# Processing Record 12 of Set 11 | comodoro rivadavia
# Processing Record 13 of Set 11 | goderich
# Processing Record 14 of Set 11 | sakakah
# Processing Record 15 of Set 11 | bojaya
# City not found. Skipping...
# Processing Record 16 of Set 11 | san patricio
# Processing Record 17 of Set 11 | awjilah
# Processing Record 18 of Set 11 | preobrazheniye
# Processing Record 19 of Set 11 | aykhal
# Processing Record 20 of Set 11 | zhigalovo
# Processing Record 21 of Set 11 | terra santa
# Processing Record 22 of Set 11 | cobija
# Processing Record 23 of Set 11 | coquimbo
# Processing Record 24 of Set 11 | pacifica
# Processing Record 25 of Set 11 | mapastepec
# Processing Record 26 of Set 11 | radcliff
# Processing Record 27 of Set 11 | muros
# Processing Record 28 of Set 11 | dingle
# Processing Record 29 of Set 11 | aripuana
# Processing Record 30 of Set 11 | mantua
# Processing Record 31 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 11 | teguise
# Processing Record 33 of Set 11 | canutama
# Processing Record 34 of Set 11 | masterton
# Processing Record 35 of Set 11 | tirat karmel
# Processing Record 36 of Set 11 | praia da vitoria
# Processing Record 37 of Set 11 | khuzhir
# Processing Record 38 of Set 11 | buala
# Processing Record 39 of Set 11 | bambanglipuro
# Processing Record 40 of Set 11 | sekoma
# Processing Record 41 of Set 11 | kovur
# Processing Record 42 of Set 11 | benghazi
# Processing Record 43 of Set 11 | sozimskiy
# Processing Record 44 of Set 11 | smithers
# Processing Record 45 of Set 11 | seoul
# Processing Record 46 of Set 11 | paracuru
# Processing Record 47 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 48 of Set 11 | morondava
# Processing Record 49 of Set 11 | calvinia
# Processing Record 50 of Set 11 | gualaquiza
# Processing Record 1 of Set 12 | arlit
# Processing Record 2 of Set 12 | lake charles
# Processing Record 3 of Set 12 | ozinki
# Processing Record 4 of Set 12 | kaseda
# Processing Record 5 of Set 12 | jasper
# Processing Record 6 of Set 12 | caluquembe
# Processing Record 7 of Set 12 | flin flon
# Processing Record 8 of Set 12 | humaita
# Processing Record 9 of Set 12 | sorland
# Processing Record 10 of Set 12 | chabahar
# Processing Record 11 of Set 12 | gornopravdinsk
# Processing Record 12 of Set 12 | abalak
# Processing Record 13 of Set 12 | berdigestyakh
# Processing Record 14 of Set 12 | pandan
# Processing Record 15 of Set 12 | nieuw amsterdam
# Processing Record 16 of Set 12 | shimanovsk
# Processing Record 17 of Set 12 | buta
# Processing Record 18 of Set 12 | airai
# Processing Record 19 of Set 12 | outjo
# Processing Record 20 of Set 12 | road town
# Processing Record 21 of Set 12 | bereda
# Processing Record 22 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 23 of Set 12 | eirunepe
# Processing Record 24 of Set 12 | manowa
# Processing Record 25 of Set 12 | imbituba
# Processing Record 26 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 27 of Set 12 | candolim
# Processing Record 28 of Set 12 | kishi
# Processing Record 29 of Set 12 | sambava
# Processing Record 30 of Set 12 | xingcheng
# Processing Record 31 of Set 12 | voh
# Processing Record 32 of Set 12 | pokrovskoye
# Processing Record 33 of Set 12 | champoton
# Processing Record 34 of Set 12 | bartica
# Processing Record 35 of Set 12 | skibbereen
# Processing Record 36 of Set 12 | la rioja
# Processing Record 37 of Set 12 | binabalian
# Processing Record 38 of Set 12 | tuyen quang
# Processing Record 39 of Set 12 | rundu
# Processing Record 40 of Set 12 | paracatu
# Processing Record 41 of Set 12 | la romana
# Processing Record 42 of Set 12 | camapua
# Processing Record 43 of Set 12 | beremend
# Processing Record 44 of Set 12 | riverton
# Processing Record 45 of Set 12 | santa isabel do rio negro
# Processing Record 46 of Set 12 | sistranda
# Processing Record 47 of Set 12 | fare
# Processing Record 48 of Set 12 | verkhnyaya inta
# Processing Record 49 of Set 12 | visnes
# Processing Record 50 of Set 12 | russell
# Processing Record 1 of Set 13 | rocha
# Processing Record 2 of Set 13 | luan
# Processing Record 3 of Set 13 | blagoyevo
# Processing Record 4 of Set 13 | corinto
# Processing Record 5 of Set 13 | caraballeda
# Processing Record 6 of Set 13 | gobabis
# Processing Record 7 of Set 13 | rocky mountain house
# Processing Record 8 of Set 13 | husavik
# Processing Record 9 of Set 13 | valparaiso
# Processing Record 10 of Set 13 | cockburn town
# Processing Record 11 of Set 13 | okha
# Processing Record 12 of Set 13 | ruwi
# Processing Record 13 of Set 13 | develi
# Processing Record 14 of Set 13 | urumqi
# Processing Record 15 of Set 13 | mahibadhoo
# Processing Record 16 of Set 13 | asyut
# Processing Record 17 of Set 13 | ciudad bolivar
# Processing Record 18 of Set 13 | cassilandia
# Processing Record 19 of Set 13 | maceio
# Processing Record 20 of Set 13 | sola
# Processing Record 21 of Set 13 | saldanha
# Processing Record 22 of Set 13 | berekum
# Processing Record 23 of Set 13 | sarakhs
# Processing Record 24 of Set 13 | vostok
# Processing Record 25 of Set 13 | ndjole
# Processing Record 26 of Set 13 | dwarka
# Processing Record 27 of Set 13 | shingu
# Processing Record 28 of Set 13 | ibipeba
# Processing Record 29 of Set 13 | gerash
# Processing Record 30 of Set 13 | college
# Processing Record 31 of Set 13 | jalu
# Processing Record 32 of Set 13 | ponta delgada
# Processing Record 33 of Set 13 | shache
# Processing Record 34 of Set 13 | strezhevoy
# Processing Record 35 of Set 13 | san quintin
# Processing Record 36 of Set 13 | ludvika
# Processing Record 37 of Set 13 | palana
# Processing Record 38 of Set 13 | thunder bay
# Processing Record 39 of Set 13 | novospasskoye
# Processing Record 40 of Set 13 | killybegs
# Processing Record 41 of Set 13 | banjar
# Processing Record 42 of Set 13 | karia
# Processing Record 43 of Set 13 | chiryu
# Processing Record 44 of Set 13 | bahia blanca
# Processing Record 45 of Set 13 | duluth
# Processing Record 46 of Set 13 | mount vernon
# Processing Record 47 of Set 13 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 48 of Set 13 | farafenni
# Processing Record 49 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 50 of Set 13 | acari
# Processing Record 1 of Set 14 | mbandaka
# Processing Record 2 of Set 14 | yuanping
# Processing Record 3 of Set 14 | jumla
# Processing Record 4 of Set 14 | portobelo
# Processing Record 5 of Set 14 | damietta
# Processing Record 6 of Set 14 | puerto pinasco
# City not found. Skipping...
# Processing Record 7 of Set 14 | almaznyy
# Processing Record 8 of Set 14 | brooks
# Processing Record 9 of Set 14 | havoysund
# Processing Record 10 of Set 14 | bochnia
# Processing Record 11 of Set 14 | evinayong
# Processing Record 12 of Set 14 | thai binh
# Processing Record 13 of Set 14 | cherdyn
# Processing Record 14 of Set 14 | rabat
# Processing Record 15 of Set 14 | catuday
# Processing Record 16 of Set 14 | umm lajj
# Processing Record 17 of Set 14 | tura
# Processing Record 18 of Set 14 | moussoro
# Processing Record 19 of Set 14 | makakilo city
# Processing Record 20 of Set 14 | beni suef
# Processing Record 21 of Set 14 | karakol
# Processing Record 22 of Set 14 | porto walter
# Processing Record 23 of Set 14 | marv dasht
# City not found. Skipping...
# Processing Record 24 of Set 14 | matara
# Processing Record 25 of Set 14 | magistralnyy
# Processing Record 26 of Set 14 | kendari
# Processing Record 27 of Set 14 | gafanha da encarnacao
# Processing Record 28 of Set 14 | batemans bay
# Processing Record 29 of Set 14 | charters towers
# Processing Record 30 of Set 14 | zhuhai
# Processing Record 31 of Set 14 | manacapuru
# Processing Record 32 of Set 14 | hualmay
# Processing Record 33 of Set 14 | bintulu
# Processing Record 34 of Set 14 | aswan
# Processing Record 35 of Set 14 | baykit
# Processing Record 36 of Set 14 | udachnyy
# Processing Record 37 of Set 14 | havelock
# Processing Record 38 of Set 14 | yaqui
# Processing Record 39 of Set 14 | faya
# Processing Record 40 of Set 14 | songjianghe
# Processing Record 41 of Set 14 | nirmal
# Processing Record 42 of Set 14 | conceicao do araguaia
# Processing Record 43 of Set 14 | saskylakh
# Processing Record 44 of Set 14 | alghero
# Processing Record 45 of Set 14 | atasu
# Processing Record 46 of Set 14 | derzhavinsk
# Processing Record 47 of Set 14 | santa cruz
# Processing Record 48 of Set 14 | norman wells
# Processing Record 49 of Set 14 | zacualpan
# Processing Record 50 of Set 14 | nzega
# Processing Record 1 of Set 15 | paris
# Processing Record 2 of Set 15 | campeche
# Processing Record 3 of Set 15 | nehe
# Processing Record 4 of Set 15 | vanavara
# Processing Record 5 of Set 15 | kaduy
# Processing Record 6 of Set 15 | fuling
# Processing Record 7 of Set 15 | puerto suarez
# Processing Record 8 of Set 15 | guangzhou
# Processing Record 9 of Set 15 | sulangan
# Processing Record 10 of Set 15 | junin
# Processing Record 11 of Set 15 | mogadishu
# Processing Record 12 of Set 15 | goryachiy klyuch
# Processing Record 13 of Set 15 | homer
# Processing Record 14 of Set 15 | vaniyambadi
# Processing Record 15 of Set 15 | suntar
# Processing Record 16 of Set 15 | dalbandin
# Processing Record 17 of Set 15 | kachiry
# Processing Record 18 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 19 of Set 15 | jodar
# Processing Record 20 of Set 15 | port hardy
# Processing Record 21 of Set 15 | churumuco
# City not found. Skipping...
# Processing Record 22 of Set 15 | rudnyy
# Processing Record 23 of Set 15 | ariquemes
# Processing Record 24 of Set 15 | paysandu
# Processing Record 25 of Set 15 | millbrook
# Processing Record 26 of Set 15 | krasnousolskiy
# City not found. Skipping...
# Processing Record 27 of Set 15 | turkmenabat
# Processing Record 28 of Set 15 | portland
# Processing Record 29 of Set 15 | dickinson
# Processing Record 30 of Set 15 | batagay-alyta
# Processing Record 31 of Set 15 | port augusta
# Processing Record 32 of Set 15 | praxedis guerrero
# Processing Record 33 of Set 15 | pirovskoye
# Processing Record 34 of Set 15 | necochea
# Processing Record 35 of Set 15 | mindyak
# Processing Record 36 of Set 15 | taga
# Processing Record 37 of Set 15 | belyy yar
# Processing Record 38 of Set 15 | makat
# Processing Record 39 of Set 15 | marzuq
# Processing Record 40 of Set 15 | moyale
# Processing Record 41 of Set 15 | ilinskoye-khovanskoye
# Processing Record 42 of Set 15 | kurganinsk
# Processing Record 43 of Set 15 | anuradhapura
# Processing Record 44 of Set 15 | dobryatino
# Processing Record 45 of Set 15 | olafsvik
# Processing Record 46 of Set 15 | kenai
# Processing Record 47 of Set 15 | erenhot
# Processing Record 48 of Set 15 | borogontsy
# Processing Record 49 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 50 of Set 15 | arcelia
# Processing Record 1 of Set 16 | ainazi
# Processing Record 2 of Set 16 | tonekabon
# Processing Record 3 of Set 16 | keti bandar
# Processing Record 4 of Set 16 | balkanabat
# Processing Record 5 of Set 16 | saint-augustin
# Processing Record 6 of Set 16 | mnogovershinnyy
# Processing Record 7 of Set 16 | yumen
# Processing Record 8 of Set 16 | apt
# Processing Record 9 of Set 16 | xichang
# Processing Record 10 of Set 16 | novoulyanovsk
# Processing Record 11 of Set 16 | hearst
# Processing Record 12 of Set 16 | plettenberg bay
# Processing Record 13 of Set 16 | san luis
# Processing Record 14 of Set 16 | tual
# Processing Record 15 of Set 16 | luanda
# Processing Record 16 of Set 16 | valle de allende
# Processing Record 17 of Set 16 | turayf
# Processing Record 18 of Set 16 | owensboro
# Processing Record 19 of Set 16 | clifton springs
# Processing Record 20 of Set 16 | de-kastri
# Processing Record 21 of Set 16 | moerai
# Processing Record 22 of Set 16 | vestmanna
# Processing Record 23 of Set 16 | maragogi
# Processing Record 24 of Set 16 | jijiga
# Processing Record 25 of Set 16 | tungkang
# City not found. Skipping...
# Processing Record 26 of Set 16 | anshun
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Cherskiy  68.7500  161.3000    -43.10        98          46
# 1   Port Alfred -33.5906   26.8910     72.57        92          88
# 2         Pisco -13.7000  -76.2167     70.02        73         100
# 3     Mahebourg -20.4081   57.7000     71.26        73          37
# 4        Avarua -21.2078 -159.7750     82.45        83          75
# 5  Puerto Ayora  -0.7393  -90.3518     73.63        89         100
# 6       Ushuaia -54.8000  -68.3000     51.46        71          75
# 7         Khash  28.2211   61.2158     43.39        33           0
# 8         Yanam  16.7333   82.2167     70.20        93          32
# 9     Cape Town -33.9258   18.4232     68.41        79           0
#
#    Wind Speed Country                 Date Current Description
# 0        3.51      RU  2022-01-27 00:45:06    scattered clouds
# 1        4.05      ZA  2022-01-27 00:45:07     overcast clouds
# 2       19.57      PE  2022-01-27 00:45:07                mist
# 3        9.89      MU  2022-01-27 00:45:07          light rain
# 4       12.66      CK  2022-01-27 00:45:08       broken clouds
# 5        7.14      EC  2022-01-27 00:45:08     overcast clouds
# 6       31.07      AR  2022-01-27 00:45:09       broken clouds
# 7        1.25      IR  2022-01-27 00:45:10           clear sky
# 8        3.58      IN  2022-01-27 00:42:52    scattered clouds
# 9        3.00      ZA  2022-01-27 00:41:07           clear sky

# %%
#Drop date column
city_data_df = city_data_df.drop(columns=["Date"])
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Cherskiy  68.7500  161.3000    -43.10        98          46        3.51
# 1  Port Alfred -33.5906   26.8910     72.57        92          88        4.05
# 2        Pisco -13.7000  -76.2167     70.02        73         100       19.57
# 3    Mahebourg -20.4081   57.7000     71.26        73          37        9.89
# 4       Avarua -21.2078 -159.7750     82.45        83          75       12.66
#
#   Country Current Description
# 0      RU    scattered clouds
# 1      ZA     overcast clouds
# 2      PE                mist
# 3      MU          light rain
# 4      CK       broken clouds

# %%
#Reorder Columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Cherskiy      RU  68.7500  161.3000    -43.10        98          46
# 1  Port Alfred      ZA -33.5906   26.8910     72.57        92          88
# 2        Pisco      PE -13.7000  -76.2167     70.02        73         100
# 3    Mahebourg      MU -20.4081   57.7000     71.26        73          37
# 4       Avarua      CK -21.2078 -159.7750     82.45        83          75
#
#    Wind Speed Current Description
# 0        3.51    scattered clouds
# 1        4.05     overcast clouds
# 2       19.57                mist
# 3        9.89          light rain
# 4       12.66       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
